# %%
! pip install torch_geometric
import torch
import torch.nn.functional as F
from torch.nn import Linear, ReLU, Sequential as Seq
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import add_self_loops, degree

class GraphNetwork(MessagePassing):
    def __init__(self, in_channels, hidden_dim, msg_dim, out_channels, aggr='add'):
        """
        A simple Graph Neural Network (GNN) using PyTorch Geometric.

        Args:
        - in_channels (int): Number of input node features.
        - hidden_dim (int): Dimension of hidden layers.
        - msg_dim (int): Dimension of message embeddings.
        - out_channels (int): Number of output node features.
        - aggr (str, optional): Aggregation method ('add', 'mean', 'max'). Default is 'add'.
        """
        super(GraphNetwork, self).__init__(aggr=aggr)  # Define aggregation method

        # Message function: transforms concatenated node pairs into edge messages
        self.message_net = Seq(
            Linear(2 * in_channels, hidden_dim),
            ReLU(),
            Linear(hidden_dim, msg_dim)
        )

        # Update function: transforms node features after aggregation
        self.update_net = Seq(
            Linear(msg_dim + in_channels, hidden_dim),
            ReLU(),
            Linear(hidden_dim, out_channels)
        )

    def forward(self, x, edge_index):
        """
        Forward pass through the GNN.

        Args:
        - x (torch.Tensor): Node feature matrix of shape [num_nodes, in_channels].
        - edge_index (torch.Tensor): Edge list in COO format of shape [2, num_edges].

        Returns:
        - Updated node feature matrix of shape [num_nodes, out_channels].
        """
        edge_index, _ = add_self_loops(edge_index, num_nodes=x.size(0))  # Add self-loops
        return self.propagate(edge_index, x=x)

    def message(self, x_i, x_j):
        """
        Defines the message function for edges.

        Args:
        - x_i (torch.Tensor): Node features of receiving nodes (shape: [num_edges, in_channels]).
        - x_j (torch.Tensor): Node features of sending nodes (shape: [num_edges, in_channels]).

        Returns:
        - Message embeddings of shape [num_edges, msg_dim].
        """
        edge_features = torch.cat([x_i, x_j], dim=1)  # Concatenate sender & receiver features
        return self.message_net(edge_features)  # Transform via message network

    def aggregate(self, inputs, index, dim_size=None):
        """
        Aggregation function (sum, mean, or max).

        Args:
        - inputs (torch.Tensor): Messages from neighbors.
        - index (torch.Tensor): Node indices corresponding to messages.

        Returns:
        - Aggregated messages per node.
        """
        out = torch.zeros(dim_size, inputs.size(1), device=inputs.device)  # Initialize output tensor
        out.scatter_add_(0, index.unsqueeze(-1).expand_as(inputs), inputs)  # Aggregate using scatter_add_
        return out

    def update(self, aggr_out, x):
        """
        Node update function.

        Args:
        - aggr_out (torch.Tensor): Aggregated messages for each node.
        - x (torch.Tensor): Original node features.

        Returns:
        - Updated node features.
        """
        combined = torch.cat([x, aggr_out], dim=1)  # Combine original features & aggregated messages
        return self.update_net(combined)  # Apply transformation via update network

# Example Usage
if __name__ == "__main__":
    from torch_geometric.data import Data

    # Define a simple graph with 4 nodes and 5 edges
    edge_index = torch.tensor([[0, 1, 1, 2, 2, 3],  # Source nodes
                               [1, 0, 2, 1, 3, 2]], dtype=torch.long)  # Target nodes

    x = torch.randn(4, 8)  # Random node features (4 nodes, 8 features each)

    # Create a graph data object
    data = Data(x=x, edge_index=edge_index)

    # Define and apply the model
    model = GraphNetwork(in_channels=8, hidden_dim=32, msg_dim=16, out_channels=8)
    updated_x = model(data.x, data.edge_index)

    print("Updated Node Features:")
    print(updated_x)
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.0.3.tar.gz (370 kB)
#      |████████████████████████████████| 370 kB 8.9 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (1.19.5)
# Requirement already satisfied: tqdm in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (4.64.1)
# Requirement already satisfied: scipy in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (1.5.4)
# Collecting networkx
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 58.7 MB/s
# Requirement already satisfied: scikit-learn in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (0.24.2)
# Requirement already satisfied: requests in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (2.27.1)
# Requirement already satisfied: pandas in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (1.1.5)
# Collecting rdflib
#   Downloading rdflib-5.0.0-py3-none-any.whl (231 kB)
#      |████████████████████████████████| 231 kB 46.3 MB/s
# Collecting googledrivedownloader
#   Downloading googledrivedownloader-0.4-py2.py3-none-any.whl (3.9 kB)
# Requirement already satisfied: jinja2 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (3.0.3)
# Requirement already satisfied: pyparsing in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (3.1.4)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: PyYAML in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from torch_geometric) (6.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from jinja2->torch_geometric) (2.0.1)
# Collecting decorator<5,>=4.3
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: pytz>=2017.2 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from pandas->torch_geometric) (2024.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from pandas->torch_geometric) (2.9.0.post0)
# Requirement already satisfied: six in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from rdflib->torch_geometric) (1.17.0)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 150 kB/s
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from requests->torch_geometric) (1.26.20)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from requests->torch_geometric) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from requests->torch_geometric) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from scikit-learn->torch_geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from scikit-learn->torch_geometric) (1.1.1)
# Requirement already satisfied: importlib-resources in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from tqdm->torch_geometric) (5.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/yi260/venvs/final_project/lib/python3.6/site-packages (from importlib-resources->tqdm->torch_geometric) (3.6.0)
# Using legacy 'setup.py install' for torch-geometric, since package 'wheel' is not installed.
# Installing collected packages: isodate, decorator, yacs, rdflib, networkx, googledrivedownloader, torch-geometric
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#     Running setup.py install for torch-geometric ... done
# Successfully installed decorator-4.4.2 googledrivedownloader-0.4 isodate-0.6.1 networkx-2.5.1 rdflib-5.0.0 torch-geometric-2.0.3 yacs-0.1.8
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-02a3e91fb92f> in <module>
#       3 import torch.nn.functional as F
#       4 from torch.nn import Linear, ReLU, Sequential as Seq
# ----> 5 from torch_geometric.nn import MessagePassing
#       6 from torch_geometric.utils import add_self_loops, degree
#       7
#
# ~/venvs/final_project/lib64/python3.6/site-packages/torch_geometric/__init__.py in <module>
#       2 from importlib import import_module
#       3
# ----> 4 import torch_geometric.data
#       5 import torch_geometric.loader
#       6 import torch_geometric.transforms
#
# ~/venvs/final_project/lib64/python3.6/site-packages/torch_geometric/data/__init__.py in <module>
# ----> 1 from .data import Data
#       2 from .hetero_data import HeteroData
#       3 from .temporal import TemporalData
#       4 from .batch import Batch
#       5 from .dataset import Dataset
#
# ~/venvs/final_project/lib64/python3.6/site-packages/torch_geometric/data/data.py in <module>
#       1 from typing import (Optional, Dict, Any, Union, List, Iterable, Tuple,
#       2                     NamedTuple, Callable)
# ----> 3 from torch_geometric.typing import OptTensor, NodeType, EdgeType
#       4 from torch_geometric.deprecation import deprecated
#       5
#
# ~/venvs/final_project/lib64/python3.6/site-packages/torch_geometric/typing.py in <module>
#       2
#       3 from torch import Tensor
# ----> 4 from torch_sparse import SparseTensor
#       5
#       6 # Types for accessing data ####################################################
#
# ModuleNotFoundError: No module named 'torch_sparse'

# %%
# create simulation data
import simulate

# Number of simulations to run (it's fast, don't worry):
ns = 10000
# Potential (see below for options)
sim = 'spring'
# Number of nodes
n = 4
# Dimension
dim = 2
# Number of time steps
nt = 1000


#Standard simulation sets:
n_set = [4, 8]
sim_sets = [
 {'sim': 'r1', 'dt': [5e-3], 'nt': [1000], 'n': n_set, 'dim': [2, 3]},
 {'sim': 'r2', 'dt': [1e-3], 'nt': [1000], 'n': n_set, 'dim': [2, 3]},
 {'sim': 'spring', 'dt': [1e-2], 'nt': [1000], 'n': n_set, 'dim': [2, 3]},
 {'sim': 'string', 'dt': [1e-2], 'nt': [1000], 'n': [30], 'dim': [2]},
 {'sim': 'charge', 'dt': [1e-3], 'nt': [1000], 'n': n_set, 'dim': [2, 3]},
 {'sim': 'superposition', 'dt': [1e-3], 'nt': [1000], 'n': n_set, 'dim': [2, 3]},
 {'sim': 'damped', 'dt': [2e-2], 'nt': [1000], 'n': n_set, 'dim': [2, 3]},
 {'sim': 'discontinuous', 'dt': [1e-2], 'nt': [1000], 'n': n_set, 'dim': [2, 3]},
]


#Select the hand-tuned dt value for a smooth simulation
# (since scales are different in each potential):
dt = [ss['dt'][0] for ss in sim_sets if ss['sim'] == sim][0]

title = '{}_n={}_dim={}_nt={}_dt={}'.format(sim, n, dim, nt, dt)
print('Running on', title)

from simulate import SimulationDataset
s = SimulationDataset(sim, n=n, dim=dim, nt=nt//2, dt=dt)
# Update this to your own dataset, or regenerate:
base_str = './'
data_str = title
s.simulate(ns)
# Out:
# Running on spring_n=4_dim=2_nt=1000_dt=0.01

# %%
import numpy as np
accel_data = s.get_acceleration()
with open('data.npy', 'wb') as f:
    np.save(f, s.data)
with open('accel.npy', 'wb') as f:
    np.save(f, accel_data)
    
# np.save(s.data, "data.npy")
# np.save(accel_data, "data.npy")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import numpy as np
#       2 accel_data = s.get_acceleration()
# ----> 3 np.save(s.data, "data.npy")
#       4 np.save(accel_data, "data.npy")
#
# File ~/.conda/envs/final/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:574, in save(file, arr, allow_pickle, fix_imports)
#     572     file_ctx = contextlib.nullcontext(file)
#     573 else:
# --> 574     file = os.fspath(file)
#     575     if not file.endswith('.npy'):
#     576         file = file + '.npy'
#
# TypeError: expected str, bytes or os.PathLike object, not ArrayImpl

# %%
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-2.6.0+cu124.html
# Collecting torch-scatter
#   Using cached torch_scatter-2.1.2.tar.gz (108 kB)
#   Preparing metadata (setup.py) ... one
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.done
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl size=545146 sha256=d7ea2dd577c912673af4bf3dfc7cc23cc723170c3065fafa7c93d866f0cc71ff
#   Stored in directory: /home/yi260/.cache/pip/wheels/92/f1/2b/3b46d54b134259f58c8363568569053248040859b1a145b3ce
# Successfully built torch-scatter
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.1.2
# Looking in links: https://pytorch-geometric.com/whl/torch-2.6.0+cu124.html
# Collecting torch-sparse
#   Using cached torch_sparse-0.6.18.tar.gz (209 kB)
#   Preparing metadata (setup.py) ... one
# Requirement already satisfied: scipy in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-sparse) (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from scipy->torch-sparse) (2.2.3)
# Building wheels for collected packages: torch-sparse
#   Building wheel fdone
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl size=1119715 sha256=3b93d4735f95f98b0fdee100bb1d5dd93ccbf3f6060e35d77922c61f58b0a2e0
#   Stored in directory: /home/yi260/.cache/pip/wheels/c9/dd/0f/a6a16f9f3b0236733d257b4b4ea91b548b984a341ed3b8f38c
# Successfully built torch-sparse
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.18
# Requirement already satisfied: torch-geometric in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: aiohttp in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-geometric) (3.11.12)
# Requirement already satisfied: fsspec in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-geometric) (2025.2.0)
# Requirement already satisfied: jinja2 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-geometric) (3.1.5)
# Requirement already satisfied: numpy in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-geometric) (2.2.3)
# Requirement already satisfied: psutil>=5.8.0 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-geometric) (7.0.0)
# Requirement already satisfied: pyparsing in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-geometric) (3.2.1)
# Requirement already satisfied: requests in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: tqdm in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from aiohttp->torch-geometric) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from aiohttp->torch-geometric) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from aiohttp->torch-geometric) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from aiohttp->torch-geometric) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from aiohttp->torch-geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from aiohttp->torch-geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from aiohttp->torch-geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from aiohttp->torch-geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from jinja2->torch-geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from requests->torch-geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from requests->torch-geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from requests->torch-geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from requests->torch-geometric) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/yi260/.conda/envs/final/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp->torch-geometric) (4.12.2)

# %%
# setup model
import pytorch



model =
